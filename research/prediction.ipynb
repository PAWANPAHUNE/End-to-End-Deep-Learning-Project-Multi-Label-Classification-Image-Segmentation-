# %%
import os
import sys
import numpy as np
# 1. Move the notebook's working directory up to the project root
# %cd "/Users/pawanpahune/End to End Deep Learning Project "

# 2. Add the root to sys.path so Python can see the 'src' directory
project_root = os.getcwd()
if project_root not in sys.path:
    sys.path.append(project_root)

# 3. Import your pipeline now that paths are aligned
from src.End_to_End_DL_Project.pipeline.prediction_pipeline import PredictionPipeline

# 4. Run your test function
def test_prediction(img_path):
    pipeline = PredictionPipeline(filename=img_path)
    prediction_result = pipeline.predict()
    
    predicted_class = prediction_result[0]["image"]
    print(f"\nPredicted Class: {predicted_class}")
    return predicted_class

# Execute test
image_path = "Data_Samples_for_UI/data/test/large.cell.carcinoma/000116.png"
predicted = test_prediction(image_path)
# Out:
# /Users/pawanpahune/End to End Deep Learning Project
# [2026-06-15 09:02:15,842: WARNING: saving_utils: Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
#
# Predicted Class: Large Cell Carcinoma
